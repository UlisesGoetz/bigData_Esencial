# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/Mr.R/Downloads/archivos_base_python_data_science_big_data_esencial/base_datos_2008.csv",nrows=10000)

# %%
df.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# ...

# %%
df.tail(10)
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 9990  2008      1           6          7    635.0         635    900.0
# 9991  2008      1           6          7   1845.0        1720   2005.0
# 9992  2008      1           6          7   1644.0        1400   1753.0
# 9993  2008      1           6          7   1220.0        1150   1649.0
# 9994  2008      1           6          7    900.0         905   1009.0
# 9995  2008      1           6          7   2000.0        1955   2121.0
# 9996  2008      1           6          7   1624.0        1620   1742.0
# 9997  2008      1           6          7   1946.0        1805   2059.0
# 9998  2008      1           6          7   1549.0        1430   1706.0
# 9999  2008      1           6          7   1050.0        1050   1211.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 9990         850            WN       2452  ...    7.0     21.0          0
# ...

# %%
df=df.sample(frac=1)

# %%
df
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1216  2008      1           3          4   1049.0        1050   1316.0
# 456   2008      1           3          4    703.0         705    808.0
# 6160  2008      1           5          6   1823.0        1815   2024.0
# 7946  2008      1           5          6   1839.0        1755   1903.0
# 5070  2008      1           4          5    611.0         610    720.0
# ...    ...    ...         ...        ...      ...         ...      ...
# 1010  2008      1           3          4    700.0         700    822.0
# 6325  2008      1           5          6   1809.0        1810   1852.0
# 7367  2008      1           5          6   1234.0        1235   1347.0
# 3239  2008      1           4          5   1144.0        1145   1439.0
# 8105  2008      1           5          6    833.0         820   1052.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.DepTime
# Out:
# 1216    1049.0
# 456      703.0
# 6160    1823.0
# 7946    1839.0
# 5070     611.0
#          ...
# 1010     700.0
# 6325    1809.0
# 7367    1234.0
# 3239    1144.0
# 8105     833.0
# Name: DepTime, Length: 10000, dtype: float64

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values
# Out:
# array([[2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 5, ..., nan, nan, nan],
#        ...,
#        [2008, 1, 5, ..., nan, nan, nan],
#        [2008, 1, 4, ..., nan, nan, nan],
#        [2008, 1, 5, ..., 22.0, 0.0, 0.0]], dtype=object)

# %%
df2=df.head(10)

# %%
df2.head(12)
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1216  2008      1           3          4   1049.0        1050   1316.0
# 456   2008      1           3          4    703.0         705    808.0
# 6160  2008      1           5          6   1823.0        1815   2024.0
# 7946  2008      1           5          6   1839.0        1755   1903.0
# 5070  2008      1           4          5    611.0         610    720.0
# 4496  2008      1           4          5   1926.0        1815   2211.0
# 1083  2008      1           3          4   1503.0        1415   1729.0
# 852   2008      1           3          4    720.0         630    934.0
# 9673  2008      1           6          7   1741.0        1735   1847.0
# 3796  2008      1           4          5   1906.0        1755     41.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 1216        1310            WN       3406  ...    6.0     10.0          0
# ...

# %%
df["ArrDelay"].head()
# Out:
# 1216     6.0
# 456     -2.0
# 6160    -1.0
# 7946    33.0
# 5070    -5.0
# Name: ArrDelay, dtype: float64

# %%
df[3:10]
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 7946  2008      1           5          6   1839.0        1755   1903.0
# 5070  2008      1           4          5    611.0         610    720.0
# 4496  2008      1           4          5   1926.0        1815   2211.0
# 1083  2008      1           3          4   1503.0        1415   1729.0
# 852   2008      1           3          4    720.0         630    934.0
# 9673  2008      1           6          7   1741.0        1735   1847.0
# 3796  2008      1           4          5   1906.0        1755     41.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 7946        1830            WN        490  ...    5.0      8.0          0
# 5070         725            WN       3250  ...    3.0     10.0          0
# 4496        2110            WN       1222  ...    3.0     13.0          0
# 1083        1615            WN        237  ...    5.0     50.0          0
# ...

# %%
df[df["ArrDelay"]=="ATL"].head()
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %%
df[pd.isna(df["ArrDelay"])].head()=df2
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 6643  2008      1           5          6      NaN         840      NaN
# 1099  2008      1           3          4      NaN        1045      NaN
# 5067  2008      1           4          5      NaN        1940      NaN
# 8934  2008      1           6          7      NaN        1650      NaN
# 5336  2008      1           4          5      NaN        1050      NaN
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 6643         930            WN        626  ...    NaN      NaN          1
# 1099        1205            WN        747  ...    NaN      NaN          1
# 5067        2050            WN       1403  ...    NaN      NaN          1
# 8934        1805            WN       1398  ...    NaN      NaN          1
# 5336        1220            WN        553  ...    NaN      NaN          1
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
len(df2)
# Out:
# 10

# %%
df["HoursDelay"]= round(df["ArrDelay"])

# %%
df["HoursDelay"]
# Out:
# 1216     6.0
# 456     -2.0
# 6160    -1.0
# 7946    33.0
# 5070    -5.0
#         ...
# 1010     7.0
# 6325    -8.0
# 7367   -13.0
# 3239    -1.0
# 8105    22.0
# Name: HoursDelay, Length: 10000, dtype: float64

# %%
df.head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1216  2008      1           3          4   1049.0        1050   1316.0
# 456   2008      1           3          4    703.0         705    808.0
# 6160  2008      1           5          6   1823.0        1815   2024.0
# 7946  2008      1           5          6   1839.0        1755   1903.0
# 5070  2008      1           4          5    611.0         610    720.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 1216        1310            WN       3406  ...    6.0     10.0          0
# 456          810            WN          7  ...    3.0     14.0          0
# 6160        2025            WN       3331  ...    8.0     10.0          0
# 7946        1830            WN        490  ...    5.0      8.0          0
# 5070         725            WN       3250  ...    3.0     10.0          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
del(df["HoursDelay"])

# %%
df2 = df.drop(["Year"],axis=1)

# %%
df2.head()
# Out:
#       Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 1216      1           3          4   1049.0        1050   1316.0        1310
# 456       1           3          4    703.0         705    808.0         810
# 6160      1           5          6   1823.0        1815   2024.0        2025
# 7946      1           5          6   1839.0        1755   1903.0        1830
# 5070      1           4          5    611.0         610    720.0         725
#
#      UniqueCarrier  FlightNum TailNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 1216            WN       3406  N206WN  ...     6.0     10.0          0
# 456             WN          7  N365SW  ...     3.0     14.0          0
# 6160            WN       3331  N728SW  ...     8.0     10.0          0
# 7946            WN        490  N332SW  ...     5.0      8.0          0
# 5070            WN       3250  N706SW  ...     3.0     10.0          0
#
#       CancellationCode  Diverted CarrierDelay WeatherDelay  NASDelay  \
# ...

# %%
df2.drop(range(0,10000))
# Out:
# Empty DataFrame
# Columns: [Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1216  2008      1           3          4   1049.0        1050   1316.0
# 456   2008      1           3          4    703.0         705    808.0
# 6160  2008      1           5          6   1823.0        1815   2024.0
# 7946  2008      1           5          6   1839.0        1755   1903.0
# 5070  2008      1           4          5    611.0         610    720.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 1216        1310            WN       3406  ...    6.0     10.0          0
# 456          810            WN          7  ...    3.0     14.0          0
# 6160        2025            WN       3331  ...    8.0     10.0          0
# 7946        1830            WN        490  ...    5.0      8.0          0
# 5070         725            WN       3250  ...    3.0     10.0          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 
np.random.seed(5)
df= pd.read_csv("C:/Users/Mr.R/Downloads/archivos_base_python_data_science_big_data_esencial/base_datos_2008.csv",nrows=100000)
df = df.sample(frac=1).head(100)
data=np.unique(df.DayOfWeek,return_counts=True)
labs=["lunes","martes","miercoles","jueves","viernes"]
data
# Out:
# (array([1, 2, 3, 4, 5, 6, 7], dtype=int64),
#  array([16,  9, 16, 15, 19,  9, 16], dtype=int64))

# %%
plt.scatter(x=df.DayofMonth,y=df.ArrDelay, s = df.Distance, alpha= 0.3)

# %%
plt.pie(data[1],
       labels=data[0],
       radius = 1.5,
       colors=["Red","Green","Orange","Blue","Gray","Pink","Yellow"],
        explode= (0.1,0,0.1,0,0.3,0,.1),
        startangle=90,
        autopct="%1.1f%%",
       )
plt.show()

# %%
plt = sns.barplot(x=data[0], y= data[1])
plt.set(xlabel = "Dia de la semana", ylabel="Numero de vuelos")
# Out:
# [Text(0.5, 0, 'Dia de la semana'), Text(0, 0.5, 'Dia de vuelo')]

# %%
# Out:
# '%1.1f%%'

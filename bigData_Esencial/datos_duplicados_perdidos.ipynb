# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/Mr.R/Downloads/archivos_base_python_data_science_big_data_esencial/base_datos_2008.csv",nrows=1e6)

# %%
df.head(100)
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   2008      1           3          4   2003.0        1955   2211.0
# 1   2008      1           3          4    754.0         735   1002.0
# 2   2008      1           3          4    628.0         620    804.0
# 3   2008      1           3          4    926.0         930   1054.0
# 4   2008      1           3          4   1829.0        1755   1959.0
# ..   ...    ...         ...        ...      ...         ...      ...
# 95  2008      1           3          4   1506.0        1440   2030.0
# 96  2008      1           3          4   2039.0        1930    155.0
# 97  2008      1           3          4    924.0         920   1209.0
# 98  2008      1           3          4   1611.0        1535   1849.0
# 99  2008      1           3          4   1824.0        1715    117.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
dfduplicate=df.append(df)

# %%
dfdfduplicate=dfduplicate.sample(frac=1)

# %%
dfclean=dfdfduplicate.drop_duplicates()

# %%
len(dfclean)
# Out:
# 999996

# %%
len(dfdfduplicate)
# Out:
# 2000000

# %%
len(df)
# Out:
# 1000000

# %%
df31dias=dfclean.drop_duplicates(subset="DayofMonth")

# %%
len(df31dias)
# Out:
# 31

# %%
df31dias.head(100)
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 978292  2008      2           5          2    810.0         815   1059.0
# 431530  2008      1          29          2   1611.0        1619   1823.0
# 973004  2008      2          11          1   1127.0        1125   1344.0
# 388141  2008      1          21          1   1111.0        1115   1155.0
# 439676  2008      1           6          7   1529.0        1531   1742.0
# 143272  2008      1          20          7   1357.0        1409   1652.0
# 406730  2008      1           4          5   2001.0        2005   2252.0
# 336582  2008      1          31          4   1158.0        1155   1348.0
# 468564  2008      1           9          3    927.0         930   1054.0
# 877251  2008      2          24          7    653.0         645    856.0
# 519659  2008      1          12          6   1335.0        1335   1640.0
# 539425  2008      1          15          2      NaN         945      NaN
# ...

# %%
df.dropna(thresh=len(df.columns)-2)
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4       2008      1           3          4   1829.0        1755   1959.0
# 6       2008      1           3          4   1937.0        1830   2037.0
# 11      2008      1           3          4   1644.0        1510   1845.0
# 16      2008      1           3          4   1452.0        1425   1640.0
# 18      2008      1           3          4   1323.0        1255   1526.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999973  2008      2          23          6   1306.0        1235   1514.0
# 999983  2008      2          28          4   1458.0        1235   1645.0
# 999988  2008      2           4          1   1754.0        1655   2056.0
# 999989  2008      2           5          2   1812.0        1655   2129.0
# 999994  2008      2          11          1   1717.0        1655   2030.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...
